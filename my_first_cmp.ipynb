# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashaduzzaman12/Machine_learning/blob/main/my_first_cmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *My first ml model *

# %%
import pandas as pd

db=pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
db
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# ## Data Framing and check

# %%
y=db['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x=db.drop('logS',axis=1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=50)
x_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 275    2.0456  128.558                0.0            0.750000
# 538    1.0415  281.352                3.0            0.000000
# 339    0.7004  232.239                2.0            0.352941
# 951    0.9722  108.144                1.0            0.750000
# 980    0.5379  218.256                2.0            0.375000
# ...       ...      ...                ...                 ...
# 1141   3.6096  308.333                4.0            0.695652
# 229    2.3376  130.231                4.0            0.000000
# 70     1.8812   92.569                1.0            0.000000
# 132    5.9672  291.992                1.0            0.750000
# 109    5.0699  228.420               13.0            0.000000
#
# [915 rows x 4 columns]

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 738    1.5629  118.139                0.0                 1.0
# 731    1.7816  362.466                2.0                 0.0
# 821    0.8682  137.138                1.0                 0.6
# 254    1.1673   88.150                2.0                 0.0
# 925    3.3716  203.351                6.0                 0.0
# ...       ...      ...                ...                 ...
# 82     2.7527   98.189                4.0                 0.0
# 7      1.4054  118.176                4.0                 0.0
# 455    0.7949  212.249                3.0                 0.0
# 720    3.7268  236.740                0.0                 0.0
# 1000   2.9767  112.216                2.0                 0.0
#
# [229 rows x 4 columns]

# %% [markdown]
# ## **Models**

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %% [markdown]
# Apply the model for make prediction

# %%
y_lr_train_pred=lr.predict(x_train)
y_lr_test_pred=lr.predict(x_test)

# %%
print(y_lr_train_pred)
# Out:
# [-2.42475538e+00 -2.30959121e+00 -1.89720542e+00 -1.47471572e+00
#  -1.69282480e+00 -1.28486233e+00 -8.32549678e-02 -3.35863084e+00
#  -3.10589572e+00 -4.75460106e+00 -4.09749449e-01 -1.92430882e+00
#  -1.41879981e+00 -2.40376337e+00 -3.75552587e+00 -4.16020313e+00
#  -3.32571781e+00 -2.50558484e+00 -1.58847565e+00 -4.62920872e+00
#  -4.35385640e+00 -3.37572031e+00 -1.03700946e+00 -2.36241542e+00
#   5.07467533e-03 -1.81238524e+00 -7.51861233e+00 -2.95891063e+00
#  -2.74703999e+00 -1.82725726e+00 -1.69656716e+00 -2.21640369e+00
#  -5.64647629e-01 -2.63007977e+00 -1.03838467e+00 -3.13589412e+00
#  -2.35313211e+00 -1.30456573e+00 -3.53635569e+00 -3.66557991e+00
#  -2.85098286e+00 -5.35005477e+00 -7.34504966e+00 -2.39864833e+00
#  -3.56778944e+00 -6.53107807e-01 -3.37038187e-01 -6.95724869e-01
#  -4.15434231e+00 -3.82514585e+00 -5.06537554e+00 -1.28486233e+00
#  -3.81356550e+00 -3.94316207e+00 -1.69047674e+00 -1.45749147e+00
# ...

# %%
y_lr_test_pred
# Out:
# array([-2.10659297, -3.40703379, -1.51808796, -1.14103247, -3.53678755,
#         0.19191138, -4.6309475 , -4.59957021, -2.78410837, -1.18283601,
#        -1.33534628, -5.65963996, -0.68844889, -2.69835859, -0.43809332,
#        -4.67174022, -0.72220255, -1.10072505, -3.91128475,  2.15856264,
#        -3.98280574, -2.99197658, -3.70758747, -5.38846694, -3.71204713,
#        -4.38446328, -1.63620945, -1.52749281, -2.7588597 , -4.16869453,
#        -7.85171892, -2.56769902, -2.16323177, -1.8299197 , -2.72756129,
#        -1.9079316 , -1.75755517, -3.49637084, -1.65567409, -5.27811096,
#        -1.59489221, -2.52091556, -3.15180116, -5.52238807, -2.08611838,
#        -6.55650728, -0.30317203, -1.93075142, -5.75487595, -0.4483993 ,
#        -4.94591937, -1.82239553, -5.60250838, -2.55390464, -4.64102269,
#        -3.12061212, -0.76061733, -1.17747874, -3.30506279, -4.32260588,
#        -2.21640369, -3.402038  , -1.46641942, -0.48712419, -0.56703003,
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
lr_train_mse=mean_squared_error(y_train,y_lr_train_pred)
lr_train_r2=r2_score(y_train,y_lr_train_pred)

lr_test_mse=mean_squared_error(y_test,y_lr_test_pred)
lr_test_r2=r2_score(y_test,y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 1.0212996228814304

# %%
lr_train_r2
# Out:
# 0.7782224632315871

# %%
lr_test_mse
# Out:
# 0.9687453569924434

# %%
lr_test_r2
# Out:
# 0.7257127212289676

# %% [markdown]
# # New Section
